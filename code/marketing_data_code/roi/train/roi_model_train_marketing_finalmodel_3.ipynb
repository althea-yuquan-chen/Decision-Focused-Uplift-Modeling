# %%
# %load_ext autoreload
# %autoreload 2

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.4.1

# %%
sys.path.append("..")
from model.uplift_model import *
from model.roi_model import *

# %%
import matplotlib.pyplot as plt

def plot_loss(history, *losses):
    for loss in losses:
        plt.plot(history.history[loss], label=loss)
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
count = 20

# %%
# DIRECT RANK MODEL
# 2e-3
import keras
import keras.backend as K
import tensorflow as tf
from keras.callbacks import LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from model.roi_model import *

final_model = get_direct_rank_model()
final_model.compile(loss=None, optimizer='adam')
#lambda y_true,y_pred: y_pred
print('trainable_weights')
for x in final_model.trainable_weights:
    print(x.name)
print('non_trainable_weights')
for x in final_model.non_trainable_weights:
    print(x.name)
final_model.summary()

for i in range(10, count):

    print("iteration = ", i + 1)
    
    final_model = get_direct_rank_model()
    final_model.compile(loss=None, optimizer='adam')

    mcp_save = ModelCheckpoint('../model_file/roi/marketing/final_model/direct_rank/direct_rank_marketing_model_{}.h5'.format(i+1), save_best_only=False, monitor='val_loss', mode='min', save_weights_only=True)
    history = final_model.fit([X, T, Yr, Yc], validation_split=0.2, epochs=6000, batch_size=4096000, shuffle=True, verbose=0, callbacks=[mcp_save])

    plot_loss(history, "loss", "val_loss", "obj", "val_obj")
# Out:
# trainable_weights
# p1_hidden_1/kernel:0
# p1_hidden_1/bias:0
# p1/kernel:0
# p1/bias:0
# non_trainable_weights
# Model: "model_20"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# p0_raw_features (InputLayer)    [(None, 76)]         0
# __________________________________________________________________________________________________
# p1_hidden_1 (Dense)             (None, 64)           4928        p0_raw_features[0][0]
# __________________________________________________________________________________________________
# treated_input (InputLayer)      [(None, 1)]          0
# __________________________________________________________________________________________________
# reward_input (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# cost_input (InputLayer)         [(None, 1)]          0
# __________________________________________________________________________________________________
# p1 (Dense)                      (None, 1)            65          p1_hidden_1[0][0]
# __________________________________________________________________________________________________
# tf.math.exp_81 (TFOpLambda)     (None, 1)            0           p1[0][0]
# __________________________________________________________________________________________________
# tf.math.exp_83 (TFOpLambda)     (None, 1)            0           p1[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_81 (TFOpLambda (None, 1)            0           treated_input[0][0]
# __________________________________________________________________________________________________
# tf.math.exp_80 (TFOpLambda)     (None, 1)            0           p1[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_201 (TFOpLambd (None, 1)            0           tf.math.exp_81[0][0]
#                                                                  treated_input[0][0]
# __________________________________________________________________________________________________
# tf.math.exp_82 (TFOpLambda)     (None, 1)            0           p1[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_80 (TFOpLambda (None, 1)            0           treated_input[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_203 (TFOpLambd (None, 1)            0           tf.math.exp_83[0][0]
#                                                                  tf.math.subtract_81[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_200 (TFOpLambd (None, 1)            0           tf.math.exp_80[0][0]
#                                                                  treated_input[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_80 (TFOpLamb ()                   0           tf.math.multiply_201[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_202 (TFOpLambd (None, 1)            0           tf.math.exp_82[0][0]
#                                                                  tf.math.subtract_80[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_81 (TFOpLamb ()                   0           tf.math.multiply_203[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_60 (TFOpLambda) (None, 1)            0           tf.math.multiply_200[0][0]
#                                                                  tf.math.reduce_sum_80[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_61 (TFOpLambda) (None, 1)            0           tf.math.multiply_202[0][0]
#                                                                  tf.math.reduce_sum_81[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_20 (TFOpLa (None, 1)            0           tf.math.truediv_60[0][0]
#                                                                  tf.math.truediv_61[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_208 (TFOpLambd (None, 1)            0           treated_input[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_205 (TFOpLambd (None, 1)            0           treated_input[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_207 (TFOpLambd (None, 1)            0           cost_input[0][0]
#                                                                  tf.__operators__.add_20[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_83 (TFOpLambda (None, 1)            0           tf.math.multiply_208[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_204 (TFOpLambd (None, 1)            0           reward_input[0][0]
#                                                                  tf.__operators__.add_20[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_82 (TFOpLambda (None, 1)            0           tf.math.multiply_205[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_209 (TFOpLambd (None, 1)            0           tf.math.multiply_207[0][0]
#                                                                  tf.math.subtract_83[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_206 (TFOpLambd (None, 1)            0           tf.math.multiply_204[0][0]
#                                                                  tf.math.subtract_82[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_83 (TFOpLamb ()                   0           tf.math.multiply_209[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_82 (TFOpLamb ()                   0           tf.math.multiply_206[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_62 (TFOpLambda) ()                   0           tf.math.reduce_sum_83[0][0]
#                                                                  tf.math.reduce_sum_82[0][0]
# __________________________________________________________________________________________________
# add_loss_20 (AddLoss)           ()                   0           tf.math.truediv_62[0][0]
# __________________________________________________________________________________________________
# add_metric_20 (AddMetric)       ()                   0           tf.math.truediv_62[0][0]
# ==================================================================================================
# Total params: 4,993
# Trainable params: 4,993
# Non-trainable params: 0
# __________________________________________________________________________________________________
# iteration =  11
# iteration =  12
# iteration =  13
# iteration =  14
# iteration =  15
# iteration =  16
# iteration =  17
