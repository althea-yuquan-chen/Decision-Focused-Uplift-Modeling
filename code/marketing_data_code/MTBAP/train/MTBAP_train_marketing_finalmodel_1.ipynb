# %%
# %load_ext autoreload
# %autoreload 2

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.4.1

# %%
sys.path.append("..")
from model.uplift_model import *
from model.roi_model import *
from model.mt_roi_model import *

# %%
import matplotlib.pyplot as plt

def plot_loss(history, *losses):
    for loss in losses:
        plt.plot(history.history[loss], label=loss)
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
count = 20

# %%
# S-Learner reward
# 1e-4
import keras
import keras.backend as K
import tensorflow as tf
from keras.callbacks import LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from model.mt_roi_model import *

final_model = get_mt_slearner_model()
final_model.compile(loss='mse', optimizer='adam', metrics=['mse'])
print('trainable_weights')
for x in final_model.trainable_weights:
    print(x.name)
print('non_trainable_weights')
for x in final_model.non_trainable_weights:
    print(x.name)
final_model.summary()


for i in range(count):

    print("iteration = ", i + 1)
    
    final_model = get_mt_slearner_model()
    final_model.compile(loss='mse', optimizer='adam', metrics=['mse'])

    mcp_save = ModelCheckpoint('../model_file/MTBAP/marketing/final_model/TPM/mt_slearner_marketing_reward_model_{}.h5'.format(i+1), save_best_only=True, monitor='val_loss', mode='min', save_weights_only=True)
    history = final_model.fit([X, T], Yr, validation_split=0.2, epochs=200, batch_size=4096, shuffle=True, verbose=0, callbacks=[mcp_save])

        
    plot_loss(history, "loss", "val_loss", "mse", "val_mse")
# Out:
# trainable_weights
# p1_hidden_1/kernel:0
# p1_hidden_1/bias:0
# p1_hidden_2/kernel:0
# p1_hidden_2/bias:0
# p1/kernel:0
# p1/bias:0
# non_trainable_weights
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# p0_raw_features (InputLayer)    [(None, 76)]         0
# __________________________________________________________________________________________________
# treated_input (InputLayer)      [(None, 1)]          0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 77)           0           p0_raw_features[0][0]
#                                                                  treated_input[0][0]
# __________________________________________________________________________________________________
# p1_hidden_1 (Dense)             (None, 64)           4992        concatenate[0][0]
# __________________________________________________________________________________________________
# p1_hidden_2 (Dense)             (None, 32)           2080        p1_hidden_1[0][0]
# __________________________________________________________________________________________________
# p1 (Dense)                      (None, 1)            33          p1_hidden_2[0][0]
# ==================================================================================================
# Total params: 7,105
# Trainable params: 7,105
# Non-trainable params: 0
# __________________________________________________________________________________________________
# iteration =  1
# iteration =  2
# iteration =  3
# iteration =  4
# iteration =  5
# iteration =  6
# iteration =  7
# iteration =  8
# iteration =  9
# iteration =  10
# iteration =  11
# iteration =  12
# iteration =  13
# iteration =  14
# iteration =  15
# iteration =  16
# iteration =  17
# iteration =  18
# iteration =  19
# iteration =  20

# %%
# S-Learner cost
# 1e-4
import keras
import keras.backend as K
import tensorflow as tf
from keras.callbacks import LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from model.mt_roi_model import *

final_model = get_mt_slearner_model()
final_model.compile(loss='mse', optimizer='adam', metrics=['mse'])
print('trainable_weights')
for x in final_model.trainable_weights:
    print(x.name)
print('non_trainable_weights')
for x in final_model.non_trainable_weights:
    print(x.name)
final_model.summary()


for i in range(count):

    print("iteration = ", i + 1)
    
    final_model = get_mt_slearner_model()
    final_model.compile(loss='mse', optimizer='adam', metrics=['mse'])

    mcp_save = ModelCheckpoint('../model_file/MTBAP/marketing/final_model/TPM/mt_slearner_marketing_cost_model_{}.h5'.format(i+1), save_best_only=True, monitor='val_loss', mode='min', save_weights_only=True)
    history = final_model.fit([X, T], Yc, validation_split=0.2, epochs=200, batch_size=4096, shuffle=True, verbose=0, callbacks=[mcp_save])

        
    plot_loss(history, "loss", "val_loss", "mse", "val_mse")
# Out:
# trainable_weights
# p1_hidden_1/kernel:0
# p1_hidden_1/bias:0
# p1_hidden_2/kernel:0
# p1_hidden_2/bias:0
# p1/kernel:0
# p1/bias:0
# non_trainable_weights
# Model: "model_21"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# p0_raw_features (InputLayer)    [(None, 76)]         0
# __________________________________________________________________________________________________
# treated_input (InputLayer)      [(None, 1)]          0
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 77)           0           p0_raw_features[0][0]
#                                                                  treated_input[0][0]
# __________________________________________________________________________________________________
# p1_hidden_1 (Dense)             (None, 64)           4992        concatenate_21[0][0]
# __________________________________________________________________________________________________
# p1_hidden_2 (Dense)             (None, 32)           2080        p1_hidden_1[0][0]
# __________________________________________________________________________________________________
# p1 (Dense)                      (None, 1)            33          p1_hidden_2[0][0]
# ==================================================================================================
# Total params: 7,105
# Trainable params: 7,105
# Non-trainable params: 0
# __________________________________________________________________________________________________
# iteration =  1
# iteration =  2
# iteration =  3
# iteration =  4
# iteration =  5
# iteration =  6
# iteration =  7
# iteration =  8
# iteration =  9
# iteration =  10
# iteration =  11
# iteration =  12
# iteration =  13
# iteration =  14
# iteration =  15
# iteration =  16
# iteration =  17
# iteration =  18
# iteration =  19
# iteration =  20

# %%
# multiple treatment rank roi model with customized_regularizy
# 2层nn: 0.03 0.001 1e-2
import keras
import keras.backend as K
import tensorflow as tf
from keras.callbacks import LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from model.mt_roi_model import *

final_model = get_rank_marginal_utility_model()
final_model.compile(loss=None, optimizer='adam')
print('trainable_weights')
for x in final_model.trainable_weights:
    print(x.name)
print('non_trainable_weights')
for x in final_model.non_trainable_weights:
    print(x.name)
final_model.summary()


for i in range(5,10):

    print("iteration = ", i + 1)
    
    final_model = get_rank_marginal_utility_model()
    final_model.compile(loss=None, optimizer='adam')

    mcp_save = ModelCheckpoint('../model_file/MTBAP/marketing/final_model/DPM/rank_marginal_utility_model_{}.h5'.format(i+1), save_best_only=False, monitor='val_obj', mode='min', save_weights_only=True)
    history = final_model.fit([X, T, Yr, Yc], validation_split=0.2, epochs=6000, batch_size=4096000, shuffle=True, verbose=0, callbacks=[mcp_save])

        
    plot_loss(history, "loss", "val_loss", "obj", "val_obj")
# Out:
# trainable_weights
# p1_hidden_1/kernel:0
# p1_hidden_1/bias:0
# p1/kernel:0
# p1/bias:0
# non_trainable_weights
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# p0_raw_features (InputLayer)    [(None, 76)]         0
# __________________________________________________________________________________________________
# treated_input (InputLayer)      [(None, 1)]          0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 77)           0           p0_raw_features[0][0]
#                                                                  treated_input[0][0]
# __________________________________________________________________________________________________
# p1_hidden_1 (Dense)             (None, 64)           4992        concatenate[0][0]
#                                                                  concatenate_1[0][0]
# __________________________________________________________________________________________________
# reward_input (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# cost_input (InputLayer)         [(None, 1)]          0
# __________________________________________________________________________________________________
# p1 (Dense)                      (None, 1)            65          p1_hidden_1[0][0]
#                                                                  p1_hidden_1[1][0]
# __________________________________________________________________________________________________
# tf.math.subtract (TFOpLambda)   (None, 1)            0           treated_input[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 77)           0           p0_raw_features[0][0]
#                                                                  tf.math.subtract[0][0]
# __________________________________________________________________________________________________
# tf.math.greater (TFOpLambda)    (None, 1)            0           treated_input[0][0]
# __________________________________________________________________________________________________
# tf.math.less (TFOpLambda)       (None, 1)            0           treated_input[0][0]
# __________________________________________________________________________________________________
# tf.math.square_1 (TFOpLambda)   (None, 1)            0           p1[1][0]
# __________________________________________________________________________________________________
# tf.cast (TFOpLambda)            (None, 1)            0           tf.math.greater[0][0]
# __________________________________________________________________________________________________
# tf.math.square (TFOpLambda)     (None, 1)            0           p1[0][0]
# __________________________________________________________________________________________________
# tf.cast_1 (TFOpLambda)          (None, 1)            0           tf.math.less[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_2 (TFOpLambda) (None, 1)            0           tf.math.square_1[0][0]
#                                                                  tf.cast[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_3 (TFOpLambda) (None, 1)            0           tf.math.square[0][0]
#                                                                  tf.cast_1[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply (TFOpLambda)   (None, 1)            0           p1[1][0]
#                                                                  tf.cast[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_1 (TFOpLambda) (None, 1)            0           p1[0][0]
#                                                                  tf.cast_1[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_2 (TFOpLambda) (None, 1)            0           tf.math.multiply_2[0][0]
#                                                                  tf.math.multiply_3[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_1 (TFOpLambda) (None, 1)            0           tf.math.multiply[0][0]
#                                                                  tf.math.multiply_1[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_5 (TFOpLambda) (None, 1)            0           cost_input[0][0]
#                                                                  tf.math.subtract_2[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_4 (TFOpLambda) (None, 1)            0           reward_input[0][0]
#                                                                  tf.math.subtract_1[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean_1 (TFOpLamb ()                   0           tf.math.multiply_5[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean (TFOpLambda ()                   0           tf.math.multiply_4[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_3 (TFOpLambda) ()                   0           tf.math.reduce_mean_1[0][0]
#                                                                  tf.math.reduce_mean[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_6 (TFOpLambda) ()                   0           tf.math.subtract_3[0][0]
# __________________________________________________________________________________________________
# add_loss (AddLoss)              ()                   0           tf.math.multiply_6[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_7 (TFOpLambda) ()                   0           tf.math.subtract_3[0][0]
# __________________________________________________________________________________________________
# add_metric (AddMetric)          ()                   0           tf.math.multiply_7[0][0]
# ==================================================================================================
# Total params: 5,057
# Trainable params: 5,057
# Non-trainable params: 0
# __________________________________________________________________________________________________
# iteration =  6
# iteration =  7
# iteration =  8
# iteration =  9
# iteration =  10
